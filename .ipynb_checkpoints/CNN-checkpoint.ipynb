# %%
import warnings
warnings.filterwarnings('ignore')

import ast
import math
import pandas as pd
import glob
import numpy as np
import cv2

# from simplification.cutil import simplify_coords

import matplotlib.pyplot as plt
import matplotlib.style as style

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import json
import os
import datetime as dt
from tqdm import tqdm
import pandas as pd
import numpy as np
from glob import glob
import re
import ast
# import cv2
import csv
import time
import ast
import urllib
from PIL import Image, ImageDraw
from tqdm import tqdm
from dask import bag, threaded
import matplotlib
import matplotlib.pyplot as pltc
import numpy as np
import pandas as pd 
import tensorflow as tf
import matplotlib.pyplot as plt
from dask import bag, threaded
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.nasnet import NASNetMobile
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.applications import MobileNet
from keras.models import Sequential,Model  #Input

from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
# from keras.layers.normalization import BatchNormalization
# from keras.layers.advanced_activations import LeakyReLU
import os

Base_Size = 256
num_csv = 100
num_class = 340
size = 64
steps = 2000
batchsize = 256
epochs = 100

# %%
dataset_folder = "../dataset/new/train_simplified"

# %% [markdown]
# # Shuffling doodle dataset

# %% [markdown]
# ## 1. changing dataset file Names

# %%
old_names  = []
new_names = []
new_name = "train_file{}.csv"
k = 0

for file in os.listdir(dataset_folder):
    
    old_names.append(file)
    new_names.append(new_name.format(k))
    k+=1

print(old_names)
new_names
# Out:
# ['steak.csv', 'helicopter.csv', 'snowman.csv', 'triangle.csv', 'fish.csv', 'goatee.csv', 'truck.csv', 'saxophone.csv', 'broom.csv', 'bridge.csv', 'peas.csv', 'eyeglasses.csv', 'lightning.csv', 'zigzag.csv', 'animal migration.csv', 'washing machine.csv', 'streetlight.csv', 'airplane.csv', 'camouflage.csv', 'keyboard.csv', 'penguin.csv', 'stitches.csv', 'sweater.csv', 'parachute.csv', 'sun.csv', 'stethoscope.csv', 'pliers.csv', 'pear.csv', 'river.csv', 'circle.csv', 'octagon.csv', 'calendar.csv', 'train.csv', 'headphones.csv', 'trombone.csv', 'cloud.csv', 'alarm clock.csv', 'pants.csv', 'bread.csv', 'speedboat.csv', 'bus.csv', 'windmill.csv', 'asparagus.csv', 'hedgehog.csv', 'garden.csv', 'drums.csv', 'vase.csv', 'beach.csv', 'cat.csv', 'campfire.csv', 'pond.csv', 'sailboat.csv', 'candle.csv', 'beard.csv', 'hexagon.csv', 'bench.csv', 'house.csv', 'dresser.csv', 'sheep.csv', 'rainbow.csv', 'The Great Wall of China.csv', 'rain.csv', 'garden hose.csv', 'birthday cake.csv', 'mailbox.csv', 'scorpion.csv', 'leg.csv', 'pickup truck.csv', 'computer.csv', 'cruise ship.csv', 'tennis racquet.csv', 'book.csv', 'drill.csv', 'broccoli.csv', 'ceiling fan.csv', 'passport.csv', 'stop sign.csv', 'palm tree.csv', 'boomerang.csv', 'smiley face.csv', 'grapes.csv', 'toe.csv', 'fence.csv', 'pool.csv', 'bear.csv', 'oven.csv', 'angel.csv', 'donut.csv', 'flower.csv', 'ear
# ['train_file0.csv',
#  'train_file1.csv',
#  'train_file2.csv',
#  'train_file3.csv',
#  'train_file4.csv',
#  'train_file5.csv',
#  'train_file6.csv',
#  'train_file7.csv',
#  'train_file8.csv',
#  'train_file9.csv',
#  'train_file10.csv',
#  'train_file11.csv',
#  'train_file12.csv',
#  'train_file13.csv',
#  'train_file14.csv',
#  'train_file15.csv',
#  'train_file16.csv',
#  'train_file17.csv',
#  'train_file18.csv',
#  'train_file19.csv',
#  'train_file20.csv',
#  'train_file21.csv',
#  'train_file22.csv',
#  'train_file23.csv',
#  'train_file24.csv',
#  'train_file25.csv',
#  'train_file26.csv',
#  'train_file27.csv',
#  'train_file28.csv',
#  'train_file29.csv',
#  'train_file30.csv',
#  'train_file31.csv',
#  'train_file32.csv',
#  'train_file33.csv',
#  'train_file34.csv',
#  'train_file35.csv',
#  'train_file36.csv',
#  'train_file37.csv',
#  'train_file38.csv',
#  'train_file39.csv',
#  'train_file40.csv',
#  'train_file41.csv',
#  'train_file42.csv',
#  'train_file43.csv',
#  'train_file44.csv',
#  'train_file45.csv',
#  'train_file46.csv',
#  'train_file47.csv',
#  'train_file48.csv',
#  'train_file49.csv',
#  'train_file50.csv',
#  'train_file51.csv',
#  'train_file52.csv',
#  'train_file53.csv',
#  'train_file54.csv',
#  'train_file55.csv',
#  'train_file56.csv',
#  'train_file57.csv',
#  'train_file58.csv',
#  'train_file59.csv',
#  'train_file60.csv',
#  'train_file61.csv',
#  'train_file62.csv',
#  'train_file63.csv',
#  'train_file64.csv',
#  'train_file65.csv',
#  'train_file66.csv',
#  'train_file67.csv',
#  'train_file68.csv',
#  'train_file69.csv',
#  'train_file70.csv',
#  'train_file71.csv',
#  'train_file72.csv',
#  'train_file73.csv',
#  'train_file74.csv',
#  'train_file75.csv',
#  'train_file76.csv',
#  'train_file77.csv',
#  'train_file78.csv',
#  'train_file79.csv',
#  'train_file80.csv',
#  'train_file81.csv',
#  'train_file82.csv',
#  'train_file83.csv',
#  'train_file84.csv',
#  'train_file85.csv',
#  'train_file86.csv',
#  'train_file87.csv',
#  'train_file88.csv',
#  'train_file89.csv',
#  'train_file90.csv',
#  'train_file91.csv',
#  'train_file92.csv',
#  'train_file93.csv',
#  'train_file94.csv',
#  'train_file95.csv',
#  'train_file96.csv',
#  'train_file97.csv',
#  'train_file98.csv',
#  'train_file99.csv',
#  'train_file100.csv',
#  'train_file101.csv',
#  'train_file102.csv',
#  'train_file103.csv',
#  'train_file104.csv',
#  'train_file105.csv',
#  'train_file106.csv',
#  'train_file107.csv',
#  'train_file108.csv',
#  'train_file109.csv',
#  'train_file110.csv',
#  'train_file111.csv',
#  'train_file112.csv',
#  'train_file113.csv',
#  'train_file114.csv',
#  'train_file115.csv',
#  'train_file116.csv',
#  'train_file117.csv',
#  'train_file118.csv',
#  'train_file119.csv',
#  'train_file120.csv',
#  'train_file121.csv',
#  'train_file122.csv',
#  'train_file123.csv',
#  'train_file124.csv',
#  'train_file125.csv',
#  'train_file126.csv',
#  'train_file127.csv',
#  'train_file128.csv',
#  'train_file129.csv',
#  'train_file130.csv',
#  'train_file131.csv',
#  'train_file132.csv',
#  'train_file133.csv',
#  'train_file134.csv',
#  'train_file135.csv',
#  'train_file136.csv',
#  'train_file137.csv',
#  'train_file138.csv',
#  'train_file139.csv',
#  'train_file140.csv',
#  'train_file141.csv',
#  'train_file142.csv',
#  'train_file143.csv',
#  'train_file144.csv',
#  'train_file145.csv',
#  'train_file146.csv',
#  'train_file147.csv',
#  'train_file148.csv',
#  'train_file149.csv',
#  'train_file150.csv',
#  'train_file151.csv',
#  'train_file152.csv',
#  'train_file153.csv',
#  'train_file154.csv',
#  'train_file155.csv',
#  'train_file156.csv',
#  'train_file157.csv',
#  'train_file158.csv',
#  'train_file159.csv',
#  'train_file160.csv',
#  'train_file161.csv',
#  'train_file162.csv',
#  'train_file163.csv',
#  'train_file164.csv',
#  'train_file165.csv',
#  'train_file166.csv',
#  'train_file167.csv',
#  'train_file168.csv',
#  'train_file169.csv',
#  'train_file170.csv',
#  'train_file171.csv',
#  'train_file172.csv',
#  'train_file173.csv',
#  'train_file174.csv',
#  'train_file175.csv',
#  'train_file176.csv',
#  'train_file177.csv',
#  'train_file178.csv',
#  'train_file179.csv',
#  'train_file180.csv',
#  'train_file181.csv',
#  'train_file182.csv',
#  'train_file183.csv',
#  'train_file184.csv',
#  'train_file185.csv',
#  'train_file186.csv',
#  'train_file187.csv',
#  'train_file188.csv',
#  'train_file189.csv',
#  'train_file190.csv',
#  'train_file191.csv',
#  'train_file192.csv',
#  'train_file193.csv',
#  'train_file194.csv',
#  'train_file195.csv',
#  'train_file196.csv',
#  'train_file197.csv',
#  'train_file198.csv',
#  'train_file199.csv',
#  'train_file200.csv',
#  'train_file201.csv',
#  'train_file202.csv',
#  'train_file203.csv',
#  'train_file204.csv',
#  'train_file205.csv',
#  'train_file206.csv',
#  'train_file207.csv',
#  'train_file208.csv',
#  'train_file209.csv',
#  'train_file210.csv',
#  'train_file211.csv',
#  'train_file212.csv',
#  'train_file213.csv',
#  'train_file214.csv',
#  'train_file215.csv',
#  'train_file216.csv',
#  'train_file217.csv',
#  'train_file218.csv',
#  'train_file219.csv',
#  'train_file220.csv',
#  'train_file221.csv',
#  'train_file222.csv',
#  'train_file223.csv',
#  'train_file224.csv',
#  'train_file225.csv',
#  'train_file226.csv',
#  'train_file227.csv',
#  'train_file228.csv',
#  'train_file229.csv',
#  'train_file230.csv',
#  'train_file231.csv',
#  'train_file232.csv',
#  'train_file233.csv',
#  'train_file234.csv',
#  'train_file235.csv',
#  'train_file236.csv',
#  'train_file237.csv',
#  'train_file238.csv',
#  'train_file239.csv',
#  'train_file240.csv',
#  'train_file241.csv',
#  'train_file242.csv',
#  'train_file243.csv',
#  'train_file244.csv',
#  'train_file245.csv',
#  'train_file246.csv',
#  'train_file247.csv',
#  'train_file248.csv',
#  'train_file249.csv',
#  'train_file250.csv',
#  'train_file251.csv',
#  'train_file252.csv',
#  'train_file253.csv',
#  'train_file254.csv',
#  'train_file255.csv',
#  'train_file256.csv',
#  'train_file257.csv',
#  'train_file258.csv',
#  'train_file259.csv',
#  'train_file260.csv',
#  'train_file261.csv',
#  'train_file262.csv',
#  'train_file263.csv',
#  'train_file264.csv',
#  'train_file265.csv',
#  'train_file266.csv',
#  'train_file267.csv',
#  'train_file268.csv',
#  'train_file269.csv',
#  'train_file270.csv',
#  'train_file271.csv',
#  'train_file272.csv',
#  'train_file273.csv',
#  'train_file274.csv',
#  'train_file275.csv',
#  'train_file276.csv',
#  'train_file277.csv',
#  'train_file278.csv',
#  'train_file279.csv',
#  'train_file280.csv',
#  'train_file281.csv',
#  'train_file282.csv',
#  'train_file283.csv',
#  'train_file284.csv',
#  'train_file285.csv',
#  'train_file286.csv',
#  'train_file287.csv',
#  'train_file288.csv',
#  'train_file289.csv',
#  'train_file290.csv',
#  'train_file291.csv',
#  'train_file292.csv',
#  'train_file293.csv',
#  'train_file294.csv',
#  'train_file295.csv',
#  'train_file296.csv',
#  'train_file297.csv',
#  'train_file298.csv',
#  'train_file299.csv',
#  'train_file300.csv',
#  'train_file301.csv',
#  'train_file302.csv',
#  'train_file303.csv',
#  'train_file304.csv',
#  'train_file305.csv',
#  'train_file306.csv',
#  'train_file307.csv',
#  'train_file308.csv',
#  'train_file309.csv',
#  'train_file310.csv',
#  'train_file311.csv',
#  'train_file312.csv',
#  'train_file313.csv',
#  'train_file314.csv',
#  'train_file315.csv',
#  'train_file316.csv',
#  'train_file317.csv',
#  'train_file318.csv',
#  'train_file319.csv',
#  'train_file320.csv',
#  'train_file321.csv',
#  'train_file322.csv',
#  'train_file323.csv',
#  'train_file324.csv',
#  'train_file325.csv',
#  'train_file326.csv',
#  'train_file327.csv',
#  'train_file328.csv',
#  'train_file329.csv',
#  'train_file330.csv',
#  'train_file331.csv',
#  'train_file332.csv',
#  'train_file333.csv',
#  'train_file334.csv',
#  'train_file335.csv',
#  'train_file336.csv',
#  'train_file337.csv',
#  'train_file338.csv',
#  'train_file339.csv']

# %%
import os
for i in range(len(old_names)):
#     print(old_names[i])
#     print(new_names[i])
    old_file = os.path.join(from_folder,old_names[i])
    new_file = os.path.join(from_folder,new_names[i])
    os.rename(old_file, new_file)
